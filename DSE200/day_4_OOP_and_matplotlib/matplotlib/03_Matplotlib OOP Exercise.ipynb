# %% [markdown]
# ### Matplotlib Object Oriented Programming Exercises

# %% [markdown]
# In this exercise we will write a class which will take a pandas dataframe and output a set of plots describing the dataframe. For this we will use data from http://earthquake.usgs.gov/ which maintains csv files corresponding to data of earthquake occurrences sorted according to earthquakes magnitude, ranging from significant only down to all earthquakes, major or minor. The csv files are available here

# %%
feed="http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/"

# %%
import numpy as np
import pandas as pd
#import urllib2
import matplotlib as mpl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Check if you have the updated version of Matplotlib i.e 1.5.0. If not you can udate it using linux command sudo pip install --upgrade matplotlib for unix boxes and corresponding brew command for mac

# %%
print mpl.__version__
# Out:
# 2.1.0

# %% [markdown]
# ### Acquiring Data ###
#
# For this assignment we will be working with the following csv files
#
# 1. Significant earthquakes in the last 30 days : feed + "significant_month.csv"
# 2. Magnitude > 4.5 : feed + "4.5_month.csv"
# 3. Magnitude > 2.5 : feed + "2.5_month.csv"
# 4. Magnitude > 1.0 : feed + "1.0_month.csv"

# %% [markdown]
# ### Q1 (answered)
# Write a function which takes an integer input from 1 to 4 and outputs a pandas dataframe corresponding to the csv file above. Note that the function should necessarily download the data from the website via internet.

# %%
filenames=["significant_month.csv",
           "4.5_month.csv",
           "2.5_month.csv",
           "1.0_month.csv"]
def download_data(i):
    url=feed+filenames[i-1];
    print 'downloading',url
    return pd.read_csv(url);

# %%
last_30 = download_data(1)
data_45 = download_data(2)
data_25 = download_data(3)
data_10 = download_data(4)
last_30.head()
# Out:
# downloading http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_month.csv
# downloading http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_month.csv
# downloading http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_month.csv
# downloading http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_month.csv
#                        time   latitude   longitude  depth   mag magType  \
# 0  2017-12-08T09:51:10.300Z  10.009000  140.131500  20.27  6.40     mww
# 1  2017-12-08T00:22:54.200Z  10.116400  140.219700  12.79  6.40     mww
# 2  2017-12-07T00:33:15.330Z  33.147833 -116.479167  11.14  3.96      mw
# 3  2017-12-05T04:26:38.330Z  36.373100  -97.149100   3.30  4.20     mwr
# 4  2017-12-03T11:19:06.810Z  -0.484500  -80.282300  24.73  6.00     mww
#
#      nst   gap    dmin   rms    ...                      updated  \
# 0    NaN  38.0  5.8450  1.14    ...     2017-12-08T15:16:03.040Z
# 1    NaN  13.0  5.7110  0.76    ...     2017-12-10T00:42:15.648Z
# 2  137.0  16.0  0.1197  0.21    ...     2017-12-12T18:36:02.588Z
# 3    NaN  51.0  0.1260  0.26    ...     2017-12-10T22:02:01.958Z
# 4    NaN  66.0  1.7320  1.24    ...     2017-12-05T02:54:44.983Z
#
#                                    place        type horizontalError  \
# 0           50km WNW of Fais, Micronesia  earthquake            7.60
# 1            50km NW of Fais, Micronesia  earthquake            2.10
# 2                  14km NE of Julian, CA  earthquake            0.11
# 3             15km NE of Perry, Oklahoma  earthquake            0.80
# 4  19km NE of Bahia de Caraquez, Ecuador  earthquake            6.00
#
#   depthError  magError  magNst    status  locationSource magSource
# 0       3.30     0.073    18.0  reviewed              us        us
# 1       2.80     0.041    58.0  reviewed              us        us
# 2       0.31       NaN     5.0  reviewed              ci        ci
# 3       5.50     0.038    67.0  reviewed              us        us
# 4       4.50     0.073    18.0  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
# 460   NaN   76.0   7.42200  0.87    ...     2017-12-02T04:47:24.040Z
# 461   NaN  118.0   0.72300  0.59    ...     2017-11-27T03:32:21.040Z
# 462  82.0   55.0   0.05988  0.11    ...     2017-12-13T00:04:56.040Z
# 463   NaN  177.0   1.34500  0.99    ...     2017-12-13T00:03:16.040Z
# 464   NaN  113.0   4.42400  0.81    ...     2017-11-27T19:56:07.040Z
# 465   NaN   75.0   1.40700  1.01    ...     2017-11-27T15:47:41.040Z
# 466   NaN   69.0   3.23800  1.04    ...     2017-11-27T15:05:45.332Z
# 467   NaN   87.0   1.97300  0.72    ...     2017-11-27T15:00:18.040Z
# 468   NaN  118.0   2.74300  0.86    ...     2017-11-26T21:05:46.040Z
# 469   NaN  103.0   0.76300  0.68    ...     2017-11-26T18:17:42.063Z
# 470   NaN  242.0   0.76800  0.80    ...     2017-11-26T17:00:06.040Z
# 471   NaN   62.0   0.72700  1.11    ...     2017-11-23T18:47:42.040Z
# 472   NaN  188.0   2.26900  0.73    ...     2017-11-22T21:06:54.040Z
# 473   NaN  142.0   1.65400  1.41    ...     2017-11-22T19:59:16.040Z
# 474   NaN   46.0   1.47500  0.97    ...     2017-11-22T19:44:52.040Z
# 475   NaN  101.0   0.66000  0.58    ...     2017-11-22T18:03:52.921Z
# 476   NaN  184.0  10.13800  0.81    ...     2017-11-28T08:51:11.119Z
#
#                                                  place        type  \
# 0                       87km W of Merizo Village, Guam  earthquake
# 1                      29km SSE of Palaiochora, Greece  earthquake
# 2                      33km WNW of Constitucion, Chile  earthquake
# 3           102km WSW of Ust'-Kamchatsk Staryy, Russia  earthquake
# 4                           Central Mid-Atlantic Ridge  earthquake
# 5                             58km NNE of Kerman, Iran  earthquake
# 6                               63km SE of Ravar, Iran  earthquake
# 7                             64km NNE of Kerman, Iran  earthquake
# 8                      111km NW of Saumlaki, Indonesia  earthquake
# 9                             68km NNE of Kerman, Iran  earthquake
# 10              25km S of San Juan Evangelista, Mexico  earthquake
# 11                     206km WNW of Port-Olry, Vanuatu  earthquake
# 12                         90km SSW of Paredon, Mexico  earthquake
# 13                            56km NNE of Kerman, Iran  earthquake
# 14                 2km N of Gunungwaru Satu, Indonesia  earthquake
# 15         31km NNW of Pagan, Northern Mariana Islands  earthquake
# 16                 83km S of Raoul Island, New Zealand  earthquake
# 17                         111km WNW of Iquique, Chile  earthquake
# 18                             52km S of Sola, Vanuatu  earthquake
# 19                        121km E of Port Blair, India  earthquake
# 20                           28km SW of Halabjah, Iraq  earthquake
# 21                         73km W of Tobelo, Indonesia  earthquake
# 22                          25km WSW of Halabjah, Iraq  earthquake
# 23                           137km SE of Pangai, Tonga  earthquake
# 24                             Meghalaya, India region  earthquake
# 25                               Crozet Islands region  earthquake
# 26                     261km SE of Hachijo-jima, Japan  earthquake
# 27                              84km S of Arica, Chile  earthquake
# 28                            96km NE of Hihifo, Tonga  earthquake
# 29                     49km E of Tadine, New Caledonia  earthquake
# ..                                                 ...         ...
# 447         109km ESE of L'Esperance Rock, New Zealand  earthquake
# 448                     58km W of Masachapa, Nicaragua  earthquake
# 449                           175km WNW of Alofi, Niue  earthquake
# 450                       19km SSE of Jaco, Costa Rica  earthquake
# 451           132km E of L'Esperance Rock, New Zealand  earthquake
# 452                     286km NNE of Ndoi Island, Fiji  earthquake
# 453                    80km E of Tadine, New Caledonia  earthquake
# 454                        89km S of Ndoi Island, Fiji  earthquake
# 455                           146km W of Neiafu, Tonga  earthquake
# 456                  66km ENE of Tadine, New Caledonia  earthquake
# 457                    5km WSW of Sarpol-e Zahab, Iran  earthquake
# 458                   103km E of Tadine, New Caledonia  earthquake
# 459                    56km E of Tadine, New Caledonia  earthquake
# 460  176km SW of Bristol Island, South Sandwich Isl...  earthquake
# 461                    94km E of Tadine, New Caledonia  earthquake
# 462                    22km NE of Gonzales, California  earthquake
# 463                     188km SW of Port Hardy, Canada  earthquake
# 464             202km S of Mata-Utu, Wallis and Futuna  earthquake
# 465                        94km SW of Isangel, Vanuatu  earthquake
# 466              48km WNW of Labuhankananga, Indonesia  earthquake
# 467                         100km NNE of Hihifo, Tonga  earthquake
# 468                          20km NE of Kuhdasht, Iran  earthquake
# 469                   30km WSW of Sarpol-e Zahab, Iran  earthquake
# 470                         33km SSW of Halabjah, Iraq  earthquake
# 471                    94km E of Tadine, New Caledonia  earthquake
# 472           133km E of L'Esperance Rock, New Zealand  earthquake
# 473                        68km SW of Isangel, Vanuatu  earthquake
# 474                   123km SW of Merizo Village, Guam  earthquake
# 475                   20km SSW of Sarpol-e Zahab, Iran  earthquake
# 476                         Northern East Pacific Rise  earthquake
#
#     horizontalError depthError  magError  magNst    status  locationSource  \
# 0             12.50       3.00     0.057    92.0  reviewed              us
# 1              4.60       5.20     0.074    56.0  reviewed              us
# 2              5.70       6.70     0.181     9.0  reviewed              us
# 3              8.40       4.10     0.031   323.0  reviewed              us
# 4             14.40       1.90     0.087    39.0  reviewed              us
# 5              4.40       1.90     0.075    52.0  reviewed              us
# 6              4.60       1.90     0.075    57.0  reviewed              us
# 7              6.40       1.70     0.071    19.0  reviewed              us
# 8              8.00       7.00     0.068    74.0  reviewed              us
# 9              8.70       1.90     0.083    42.0  reviewed              us
# 10             8.40       8.20     0.028   384.0  reviewed              us
# 11             7.50       2.00     0.144    16.0  reviewed              us
# 12             8.00       8.40     0.029   368.0  reviewed              us
# 13             7.50       1.80     0.073    18.0  reviewed              us
# 14             8.20       9.80     0.144    14.0  reviewed              us
# 15             9.90       7.20     0.033   270.0  reviewed              us
# 16            10.30       6.00     0.070    65.0  reviewed              us
# 17             5.70       3.10     0.061    26.0  reviewed              us
# 18             9.10       4.40     0.073    18.0  reviewed              us
# 19             9.70       7.60     0.074    54.0  reviewed              us
# 20             5.50       4.70     0.075    54.0  reviewed              us
# 21             8.40       3.70     0.101    29.0  reviewed              us
# 22             5.70       3.20     0.065    23.0  reviewed              us
# 23             9.90       2.00     0.047   158.0  reviewed              us
# 24             3.70       1.90     0.082    45.0  reviewed              us
# 25             7.30       1.90     0.097    32.0  reviewed              us
# 26             8.20       1.90     0.052   115.0  reviewed              us
# 27             4.90       6.00     0.049    40.0  reviewed              us
# 28            11.20       8.40     0.093    36.0  reviewed              us
# 29             6.50       1.90     0.073    18.0  reviewed              us
# ..              ...        ...       ...     ...       ...             ...
# 447            9.30       1.70     0.056   104.0  reviewed              us
# 448            5.40       5.90     0.052    36.0  reviewed              us
# 449            6.50       1.10     0.069    20.0  reviewed              us
# 450            5.10       4.20     0.091    36.0  reviewed              us
# 451           12.90       1.90     0.108    27.0  reviewed              us
# 452           10.40       6.80     0.073    18.0  reviewed              us
# 453            6.30       5.70     0.151    13.0  reviewed              us
# 454            8.40       7.60     0.072    56.0  reviewed              us
# 455           11.20       8.50     0.082    45.0  reviewed              us
# 456            4.90       4.40     0.087    41.0  reviewed              us
# 457            7.80       1.90     0.068    64.0  reviewed              us
# 458            6.00       2.00     0.221     6.0  reviewed              us
# 459            4.90       1.80     0.083    14.0  reviewed              us
# 460            9.10       2.00     0.107    26.0  reviewed              us
# 461            6.50       1.90     0.102    29.0  reviewed              us
# 462            0.12       0.36       NaN     6.0  reviewed              nc
# 463            5.10       2.00       NaN     NaN  reviewed              us
# 464            6.70       1.90     0.143    22.0  reviewed              us
# 465            6.20       1.70     0.115    23.0  reviewed              us
# 466            7.10       1.90     0.097    32.0  reviewed              us
# 467            5.80       5.00     0.079    51.0  reviewed              us
# 468            9.70       1.90     0.109    25.0  reviewed              us
# 469            5.10       1.80     0.056    96.0  reviewed              us
# 470            6.40       1.90     0.116    22.0  reviewed              us
# 471            6.50       1.80     0.073    18.0  reviewed              us
# 472            8.30       2.00     0.158    12.0  reviewed              us
# 473            9.00       7.20     0.139    15.0  reviewed              us
# 474           10.90       5.30     0.065    75.0  reviewed              us
# 475            5.20       1.90     0.058    90.0  reviewed              us
# 476           13.00       1.90     0.055   100.0  reviewed              us
#
#     magSource
# 0          us
# 1          us
# 2          us
# 3          us
# 4          us
# 5          us
# 6          us
# 7          us
# 8          us
# 9          us
# 10         us
# 11         us
# 12         us
# 13         us
# 14         us
# 15         us
# 16         us
# 17         us
# 18         us
# 19         us
# 20         us
# 21         us
# 22         us
# 23         us
# 24         us
# 25         us
# 26         us
# 27         us
# 28         us
# 29         us
# ..        ...
# 447        us
# 448        us
# 449        us
# 450        us
# 451        us
# 452        us
# 453        us
# 454        us
# 455        us
# 456        us
# 457        us
# 458        us
# 459        us
# 460        us
# 461        us
# 462        nc
# 463       pgc
# 464        us
# 465        us
# 466        us
# 467        us
# 468        us
# 469        us
# 470        us
# 471        us
# 472        us
# 473        us
# 474        us
# 475        us
# 476        us
#
# [477 rows x 22 columns]

# %% [markdown]
# ### Q2) Analyzing the data ###
#
# In order to understand the data we will plot different attributes of the data using tools provided by matplotlib.
# In order to do that, we will first create a class object for the given dataframe.
#
# 2.1) The class will have a set of functions to generate different plots. The first function will output a histogram taking column type as input. The column type is restricted to latitude or longitude. Take default interval size as 10 degrees
#
# 2.2) Write another function which when called will output a scatter plot of longitude vs. latitude. For extra credit represent each earthquake by a circle whose area is proporportional to the strength of the earthquake.

# %%
class dataPlot(object):
    """dataPlot takes a pandas dataframe as input and outputs different plots correspondng to the input dataframe"""
    
    def __init__(self,df):
        """Initialize variables"""
        self.df = df
        self.area = 0
    def histogram(self,col):
        mpl.pyplot.show(mpl.pyplot.hist(self.df[col], label=col, bins=range(-180, 181, 10)))
        
    def scatter(self,col1,col2):
        self.area = np.pi*(self.df.mag**2.5)
        mpl.pyplot.show(mpl.pyplot.scatter(self.df[col1], self.df[col2], s=self.area))

# %%
#The folloring command should now generate a histogram and a scatter-plot
D=dataPlot(data_45)
D.histogram('longitude')
D.scatter('longitude','latitude')

# %% [markdown]
# ### Q3) Plotting data on the map ###

# %% [markdown]
# In the last class we had used ipyleaflet to plot the weather data. Now we will use ipyleaflet to plot the earthquake data, and further enhance it with a rain animation to indicate the severity of the incident. We will start initially with the dataset corresponding to earthquakes magnitude > 4.5

# %%
data_45 = download_data(2)
# Out:
# downloading http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_month.csv

# %% [markdown]
# First we will import necessary libraries

# %%
from ipyleaflet import (
    Map,
    Marker,
    TileLayer, ImageOverlay,
    Polyline, Polygon, Rectangle, Circle, CircleMarker,
    GeoJSON,
    DrawControl
)
m = Map(center=[data_45.latitude.mean(),data_45.longitude.mean()], zoom=2)

for i in range(len(data_45)):
    c = Circle(location=(data_45.latitude[i],data_45.longitude[i]), radius=int(100000*data_45.mag[i]),size=int(data_45.mag[i]), opacity=0)
    m += c

display(m)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# Write a function that takes as input a dataframe and plots a map and on top of the map a circle at the location of each earthquake in the dataframe.
#
# Use size to convey the intensity of each earthquake. Make the the circles semi-transparent so that the intensity of the color conveys (because of multiple overlappings) the number of earthquakes that have occured.
#
# Finally wrap the function in a class that has methods for plotting an array of scatterplots from the same data-frame, each for a different time period. For example, if the data is only for Feb 2017 and you decide to plot weekly, then the function should plot four scatterplots total (2/1-2/7, 2/8-2/14 etc.)  with their corresponding earthquakes.

# %%
#!jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10

# %%
class maps(object):
    def __init__(self, df):
        self.df = df
    
    def plotmap(self):
        date = pd.date_range(start=pd.to_datetime(self.df.time.iat[-1]), end=pd.to_datetime(self.df.time.iat[0]),freq='7D')
        for i in range(len(date)):
            m = Map(center=[self.df.latitude.mean(),self.df.longitude.mean()], zoom=2)
            for j in range(len(self.df)):
                if i == len(date)-1:
                    if pd.to_datetime(self.df.time[j]) >= date[i]:
                        c = Circle(location=(self.df.latitude[j],self.df.longitude[j]), radius=int(100000*self.df.mag[j]),size=int(self.df.mag[j]), opacity=0)
                        m += c
                else:
                    if pd.to_datetime(self.df.time[j]) >= date[i] and pd.to_datetime(self.df.time[j]) < date[i+1]:
                        c = Circle(location=(self.df.latitude[j],self.df.longitude[j]), radius=int(100000*self.df.mag[j]),size=int(self.df.mag[j]), opacity=0)
                        m += c
            display(m)

# %%
a = maps(data_45)

# %%
a.plotmap()

# %% [markdown]
# # Total = 6 + 1
